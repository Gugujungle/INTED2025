# %% [markdown]
# <a href="https://colab.research.google.com/github/Gugujungle/INTED2025/blob/main/ALP_V25__Gustavo_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Algoritmo e Lógica de Programação

# %% [markdown]
# #Variáveis

# %%
a = 3  # isso é uma variável que recebe o valor 3
b = 10
print(a+b)
# Out:
# 13

# %%
a = input(int("digite um número: "))
b = input("digite outro número: ")
print(a+b)

b = int(input("digite outro número: "))
print(a+b)
# Out:
# digite um número: 16
# digite outro número: 45
# 61

# %% [markdown]
# #Tipo de dados
# int - inteiro - para números inteiros
#
# float - flutuante - para números com virgulas
#
# str - string - (caracteres) -  para palavras
#
# bool - booleano (binário) - para verdadeiro e falso

# %%
x = int(input('digite um número"'))
y = float(input("Digite um número com virgula: "))
z = str(input("Digite uma palavra"))
w = bool(input("Digite um valor booleano "))
# Out:
# digite um número" 54
# Digite um número com virgula: 1.54
# Digite uma palavra gustavo
# Digite um valor booleano True

# %%
print(x)
print(y)
print(z)
print(w)
# Out:
# 54
# 1.54
#  gustavo
# True

# %% [markdown]
# ##estrutura condicional
#
# if - se
#
# eleif - senão se
#
# else - senão

# %%
nota = float(input(" Digite sua nota: "))
if(nota >= 7):
  print("Aprovado")
elif (nota>= 5):
  print( "Recuperação")
else:
  print("Reprovado")
# Out:
#  Digite sua nota: 6.9
# Recuperação

# %% [markdown]
# ## -  Crie um algoritmo que receba a idade do usuário, e depois verifique em qual faixa etária está à idade:
#
# até 12 - Você é uma Criança!
#
# de 13 á 18 - Você é um Adolescente!
#
# de 19 à 60 - Você é um Adulto!
#
# acima de 60 - Voce é um Idoso!

# %%
idade = int(input("Digite sua idade: "))

if idade <= 12:
  print("Você é uma Criança!")
elif idade >= 13 and idade <= 18:
  print("Você é um Adolescente!")
elif idade >= 19 and idade <= 60:
  print("Você é um Adulto!")
else:
  print("Voce é um Idoso!")
# Out:
# Digite sua idade: 16
# Você é um Adolescente!
